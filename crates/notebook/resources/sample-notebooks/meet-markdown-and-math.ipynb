# %% [markdown]
# # Meet Markdown and Math
#
# Notebook markdown supports inline math like $e^{i\pi} + 1 = 0$ and display equations:
#
# $$\int_0^1 x^2 dx = \frac{1}{3}$$

# %% [markdown]
# You can also mix prose with lists:
#
# - Explain an idea
# - Add an equation
# - Follow up with executable code

# %%
sum(n * n for n in range(1, 6))
