# %%
# Notebook next to pyproject.toml
# P1: backend should auto-detect pyproject.toml on launch
# P9: deps panel shows 'Use project env' + 'Copy to notebook'
# P7: after 'Use project env', panel goes read-only
