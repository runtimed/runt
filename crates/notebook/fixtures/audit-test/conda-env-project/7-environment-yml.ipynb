# %%
# Notebook next to environment.yaml
# P2: backend should auto-detect environment.yaml on launch
# P4: deps panel shows conda banner with environment.yaml deps
