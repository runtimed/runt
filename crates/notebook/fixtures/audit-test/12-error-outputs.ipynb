# %%
exec("print(1 +")
# Out:
#   File "<string>", line 1
#     print(1 +
#          ^
# SyntaxError: '(' was never closed

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero

# %%
import nonexistent_package_xyz123
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import nonexistent_package_xyz123
#
# ModuleNotFoundError: No module named 'nonexistent_package_xyz123'

# %%
undefined_variable_xyz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 undefined_variable_xyz
#
# NameError: name 'undefined_variable_xyz' is not defined

# %%
"hello" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 "hello" + 5
#
# TypeError: can only concatenate str (not "int") to str
