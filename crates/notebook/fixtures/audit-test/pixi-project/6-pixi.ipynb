# %%
# Notebook next to pixi.toml
# P2: backend should auto-detect pixi.toml on launch
# P4: deps panel shows pixi banner with 'Copy to notebook'
